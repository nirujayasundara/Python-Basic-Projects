# %% [markdown]
# <a href="https://colab.research.google.com/github/nirujayasundara/Python-Basic-Projects/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple calculator

# %%
number1 = float(input("Enter first number: "))
number2 = float(input("Enter second number: "))

addition = number1 + number2
multiplication = number1 * number2
division = number1 / number2
floor_division = number1 // number2
remainder = number1 % number2

print("Addition:", addition)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Remainder:", remainder)
# Out:
# Enter first number: 6
# Enter second number: 7
# Addition: 13.0
# Multiplication: 42.0
# Division: 0.8571428571428571
# Floor Division: 0.0
# Remainder: 6.0
